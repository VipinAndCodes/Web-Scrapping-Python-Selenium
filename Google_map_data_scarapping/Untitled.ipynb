# %%
import requests
import googlemaps
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=12.402500225186609%2C75.10260242082579&radius=15000&type=tourist_attraction&key=AIzaSyCfqLvtrfwc_l3-v6PTM_abieRiclmd5hA"

payload={}
headers = {}


response = requests.request("GET", url, headers=headers, data=payload)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uEDHszmoR97sxRJe2Ftzk53Y0CuF4NVNFq5bvYERQaQFK33n2YakQmsI8GRgxZAH9gwrk8gHLIW20agB-THRjLTX3OypneSDTMFyuXdYVQIw4RoVhMi20g1_nZWotzl7UEQJ7AORbDMSmmau5OLpG18SiQtqBlJ8aSFONbd5sKNDMHCiyiKChtz4wx4Mb_M1nDd_Jq5juwvZGZhNATWQp0WteEFHBf2B5Hews12LFs2N6xTZm4M1dEugDAD-Y-wiKSVB2w9ydFbzxR6Xz9jqShFuU9Y9YHW3R3mVtiQgewKGhc9nWnZLy08GFa8PjUxTZBJwDyYrHFzgDtvZ1dovsGJkcyeptjB4VNZVYDxYwgr9iEDD8OzkkqnQ03jSzLRyrCAqMIKVRrbgT-S3SnB-Ni9dIXwXOVw-Y46xdS6BA_ELPFRtGmuMa7Z0qEdYKRD-jAic880",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 12.392222,
#                "lng" : 75.03298939999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 12.39556595,
#                   "lng" : 75.03431388029151
#                },
#                "southwest" : {
#                   "lat" : 12.39110735,
# ...

# %%
import json
source = response.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15344/2789810967.py in <module>
#       1 import json
# ----> 2 source = response.read()
#       3
#
# AttributeError: 'Response' object has no attribute 'read'
